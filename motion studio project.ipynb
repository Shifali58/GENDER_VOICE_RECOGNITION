# %% [markdown]
# # MOTION STUDIO PROJECT
# #(GENDER VOICE RECOGNITION)#

# %% [markdown]
# # importing necessary libraries and dataset

# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline
import math
import matplotlib.pyplot as plt

df=pd.read_csv('C:/Users/91977/Downloads/voicegender.zip')
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %% [markdown]
# # lets explore the data now

# %%
df.shape
# Out:
# (3168, 21)

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %% [markdown]
# # ANALYZING and VISUALIZING DATA

# %%
sns.countplot(x='label',data=df)

# %%
sns.stripplot(x='label', y='meanfreq',data=df)

# %%
sns.violinplot(x='label',y='skew',data=df)

# %% [markdown]
# # LETS CHECK THE CORRELATION OF COLUMNS WITH OUTPUT

# %%
sns.heatmap(df.corr(),linewidths=.25,vmax=1,square=True)

# %%
df.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %% [markdown]
# # changing the column name from label to gender

# %%
df=df.rename(columns={'label':'gender'})
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %% [markdown]
# # data wrangling

# %% [markdown]
# # checking missing values

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# gender      0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False)

# %% [markdown]
# # above code shows that there are no missing values in the data

# %% [markdown]
# # checkig for the outliers

# %%
plt.scatter(df['meanfreq'].index,df['meanfreq'])

# %%
plt.scatter(df['sd'].index,df['sd'])

# %%
df.tail(20)
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 3148  0.108888  0.092021  0.070063  0.022520  0.201180  0.178660  2.235435
# 3149  0.090445  0.079045  0.059358  0.020893  0.167727  0.146834  2.187161
# 3150  0.137507  0.091521  0.161298  0.043547  0.221260  0.177713  1.119608
# 3151  0.113148  0.090335  0.084335  0.026622  0.198830  0.172207  2.258273
# 3152  0.149731  0.082852  0.180932  0.060212  0.219788  0.159576  1.240037
# 3153  0.189614  0.035933  0.194116  0.168434  0.205289  0.036855  2.724415
# 3154  0.200097  0.045533  0.203796  0.176581  0.232133  0.055552  1.160197
# 3155  0.178573  0.046679  0.164388  0.149309  0.204601  0.055293  3.066668
# 3156  0.201806  0.036057  0.201622  0.178165  0.227872  0.049707  1.585353
# 3157  0.203627  0.041529  0.204104  0.175661  0.239122  0.063461  1.462972
# 3158  0.183667  0.040607  0.182534  0.156480  0.207646  0.051166  2.054138
# ...

# %%
df['gender'].value_counts()
# Out:
# male      1584
# female    1584
# Name: gender, dtype: int64

# %% [markdown]
# # what we have done in this is we make dummy column and store in same coulumn then dropping the female label and left with below code

# %%
gender=pd.get_dummies(df['gender'],drop_first=True)
gender
# Out:
#       male
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 3163     0
# 3164     0
# 3165     0
# 3166     0
# 3167     0
#
# [3168 rows x 1 columns]

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  gender
# ...

# %%
df.drop('gender',axis=1,inplace=True)
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# ...

# %% [markdown]
# # concatenate the gender column in data

# %%
df=pd.concat([df,gender],axis=1)
df.head(3)
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  male
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000     1
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632     1
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512     1
#
# [3 rows x 21 columns]

# %% [markdown]
# # splitting and training data

# %%
x=df.drop('male',axis=1)
y=df['male']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

# %% [markdown]
# # applying Logistic Regression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print('Accuracy1 :',model.score(x_train,y_train)*100)
print('Accuracy2 :',model.score(x_test,y_test)*100)
# Out:
# Accuracy1 : 91.04183109707972
# Accuracy2 : 91.9558359621451

# %%
pred1=log.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,pred1)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.95      0.87      0.91       315\n           1       0.88      0.96      0.92       319\n\n    accuracy                           0.92       634\n   macro avg       0.92      0.92      0.92       634\nweighted avg       0.92      0.92      0.92       634\n'

# %%
from sklearn.metrics import accuracy_score
print('ACCURACY BY LOGISTIC REGRESSION:',accuracy_score(y_test,pred1)*100)
# Out:
# ACCURACY BY LOGISTIC REGRESSION: 91.6403785488959

# %%
confusion_matrix(y_test,pred1)
# Out:
# array([[275,  40],
#        [ 13, 306]], dtype=int64)

# %% [markdown]
# # THIS IS USED FOR Standardization, or mean removal and variance scaling FOR MAKING DATA NORMAL

# %%
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
Scaler.fit(x)
x=Scaler.transform(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %% [markdown]
# # ALGORITHM SVM

# %%
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import confusion_matrix,classification_report

# %%
svc_model=SVC()
svc_model.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred=svc_model.predict(x_test)
print('ACCURACY BY SVM:',metrics.accuracy_score(y_test,y_pred)*100)
# Out:
# ACCURACY BY SVM: 97.37118822292324

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[458,  13],
#        [ 12, 468]], dtype=int64)
